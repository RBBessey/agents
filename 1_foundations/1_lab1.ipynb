# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Treat these labs as a resource</h2>
#             <span style="color:#00bfff;">I push updates to the code regularly. When people ask questions or have problems, I incorporate it in the code, adding more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but in addition, I've added more steps and better explanations. Consider this like an interactive book that accompanies the lectures.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Otherwise:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!

# %%
# First let's do an import
from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables

load_dotenv(override=True)
# Out:
# True

# %%
# Check the keys

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the guides folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting guide

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If you have a 12-liter container that is filled with water and a 5-liter container that is empty, how can you measure exactly 7 liters of water using only these two containers?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# You can measure exactly 7 liters of water using the 12-liter and 5-liter containers by following these steps:
#
# 1. **Start with the 12-liter container full** and the 5-liter container empty.
#    - 12-liter container: 12 liters
#    - 5-liter container: 0 liters
#
# 2. **Pour from the 12-liter container to the 5-liter container** until the 5-liter container is full.
#    - 12-liter container: 7 liters (12 - 5)
#    - 5-liter container: 5 liters
#
# 3. **Empty the 5-liter container.**
#    - 12-liter container: 7 liters
#    - 5-liter container: 0 liters
#
# 4. **Pour from the 12-liter container to the 5-liter container** again until the 5-liter container is full.
#    - 12-liter container: 2 liters (7 - 5)
#    - 5-liter container: 5 liters
#
# 5. **Empty the 5-liter container again.**
#    - 12-liter container: 2 liters
#    - 5-liter container: 0 liters
#
# 6. Finally, **pour from the 12-liter container to the 5-liter container** one last time.
# ...

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# You can measure exactly 7 liters of water using the 12-liter and 5-liter containers by following these steps:
#
# 1. **Start with the 12-liter container full** and the 5-liter container empty.
#    - 12-liter container: 12 liters
#    - 5-liter container: 0 liters
#
# 2. **Pour from the 12-liter container to the 5-liter container** until the 5-liter container is full.
#    - 12-liter container: 7 liters (12 - 5)
#    - 5-liter container: 5 liters
#
# 3. **Empty the 5-liter container.**
#    - 12-liter container: 7 liters
#    - 5-liter container: 0 liters
#
# 4. **Pour from the 12-liter container to the 5-liter container** again until the 5-liter container is full.
#    - 12-liter container: 2 liters (7 - 5)
#    - 5-liter container: 5 liters
#
# 5. **Empty the 5-liter container again.**
#    - 12-liter container: 2 liters
#    - 5-liter container: 0 liters
#
# 6. Finally, **pour from the 12-liter container to the 5-liter container** one last time.
# ...

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "for the company https://www.ibcos.co.uk/ please pick a buiness area with might be worth exploring for an Agentic AI opportunity "}]

# Then make the first call:

# And repeat!

# %%
response = openai.chat.completions.create(
    model="chatgpt-4o-latest",
    messages=messages
    )

business_idea = response.choices[0].message.content# Then read the business ideaanswer = response.choices[0].message.content
print(business_idea)
# Out:
# Ibcos Computers Ltd. (https://www.ibcos.co.uk/) is a UK-based company specializing in ERP software (Gold System) for agricultural, groundscare, construction, and materials handling dealers. Their solutions handle dealer management, including inventory, finance, parts, machinery sales, and servicing.
#
# A promising business area for exploring an Agentic AI opportunity:
#
# Opportunity Area: Proactive Service & Maintenance Management (After-Sales / Workshop Optimization)
#
# Why it’s a strong fit:
#
# - Ibcos’ ERP software helps dealers manage after-sales service and equipment maintenance — a critical component of customer satisfaction and revenue generation.
# - Workshops generate large volumes of information, including service logs, repair histories, parts utilization, warranty claims, and technician performance.
# - These processes are often reactive, manual, or based on fixed schedules rather than real usage data or predictive insights.
# ...

# %%
painpointQuestion = "based on these business ideas please suggestion one which you see as a the main pain point that is ripe for an Agentic Ai solution: " + business_idea

messages = [{"role": "user", "content": painpointQuestion}]

response = openai.chat.completions.create(
    model="chatgpt-4o-latest",
    messages=messages
    )

PainPoint_idea = response.choices[0].message.content# Then read the business ideaanswer = response.choices[0].message.content
print(PainPoint_idea)
# Out:
# You're right on the money with identifying "Proactive Service & Maintenance Management" as the ripest opportunity area for an Agentic AI solution within Ibcos Computers Ltd.’s business environment. Among the business ideas presented, this particular focus — the Autonomous Service Coordinator Agent — emerges as the most compelling, high-impact, and feasible entry point for applying Agentic AI. Here's a breakdown outlining why this is the strongest candidate:
#
# Main Pain Point: Service Operations Are Still Reactive & Manual
#
# Despite having access to structured ERP data (customer information, asset histories, service tickets, stock levels), dealer workshops are largely reactive in their service operations. This leads to:
#
# - Unscheduled downtime for end customers, harming satisfaction and loyalty.
# - Underutilization or overbooking of technicians, causing inefficiencies.
# - Poor forecasting of parts, leading to delayed repairs or bloated inventories.
# ...

# %%
PitchQuestion = "Please suggest the investor pitch, UX wireframe, or technical architecture sketch for this Agent-based solution  " + PainPoint_idea

messages = [{"role": "user", "content": PitchQuestion}]

response = openai.chat.completions.create(
    model="chatgpt-4o-latest",
    messages=messages
    )

Pitch_idea = response.choices[0].message.content# Then read the business ideaanswer = response.choices[0].message.content
print(Pitch_idea)
# Out:
# Absolutely — let's break down three key deliverables for your Autonomous Service Coordinator Agent initiative to bring it from vision to execution. These include:
#
# 1. Investor Pitch Deck Outline (to raise internal or external support/funding)
# 2. UX Wireframe (to envision the user-facing interface for service managers)
# 3. Technical Architecture Sketch (to validate implementation feasibility and inform engineering)
#
# I’ll provide an actionable sketch for each.
#
# ────────────────────────────────────────
# 1. Investor Pitch Deck (10-slide structure)
# ────────────────────────────────────────
#
# Slide 1: Title Slide
# Autonomous Service Coordinator Agent
# “Transforming Service Ops from Reactive to Predictive with Agentic AI”
# Ibcos Computers Ltd. | Date
#
# Slide 2: The Problem
# - 70% of dealer workshops experience unplanned technician downtime
# - Technicians are either double-booked or underutilized ~25% of the time
# - Missed service follow-ups = lost recurring revenue
# ...
