# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF2 PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# richard.bessey@hotmail.co.u
# k
# www.linkedin.com/in/gbbessey
# (LinkedIn)
# Top Skills
# Amazon Web Services (AWS)
# Microservices
# Strategic LeadershipRichard Bessey
# Hands on Engineering leadership, Senior Engineering Leader | VP
# of Platform Engineering | Director of Software Engineering & Head of
# Engineering
# Walsall, England, United Kingdom
# Summary
# I thrive on diving deep into technical challenges and working hands-
# on with customers and engineers to deliver impactful solutions. My
# leadership style is grounded in a strong engineering foundation,
# and I'm passionate about cultivating a culture of innovation,
# craftsmanship, and continuous improvement—one that empowers
# engineers and enables outcome/value driven product development.
# With over 15 years of experience across software engineering
# and engineering leadership, I've worked with teams of all sizes
# —from lean, focused squads to global engineering tribes of
# 100+ professionals. I good at right-sizing teams for maximum
# effectiveness, recognizing that in today's AI-augmented landscape,
# small high-caliber teams often deliver the most value. My blend
# of strategic vision and technical knowledge allows me to scale
# platforms, modernise architectures, and drive agile, cloud-native
# transformation in complex, regulated industries.
# I remain committed to continuous learning, recently completing
# advanced training in LLM engineering and currently building my
# first multi-agent AI solutions. This growing hands-on experience
# with emerging technologies allows me to guide teams through
# AI exploration based on practical implementation rather than just
# theoretical concepts.
# Locations: UK, Europe, and the USA
# Industries: Financial Services, Retail, and Telecommunications
# Roles: VP of Platform Engineering, Director of Software Engineering,
# and Head of Engineering
# My core skillset and key experience include:
# Emerging AI & LLM Engineering Skills (LangChain, Agent
# Architectures, Prompt Engineering)
#   Page 1 of 4
# Team Optimization for Maximum Efficiency (from lean squads to
# larger organizations)
# Digital Transformation with Measurable Impact
# Technology Modernization that Delivers Clear Business Value
# Scaling and Optimisation of Engineering Teams and Systems
# Strategy and Digital Agile Transformation
# Emotional Intelligence, Mentoring, and Coaching
# Technology Roadmaps and Modern Enterprise Architecture
# Deep Technical Full Stack Experience
# Microservices Architecture & Implementation (Java and Microsoft
# Stack)
# Cloud Engineering, Architecture, and Operating Models (Azure,
# AWS, and GCP)
# Data Strategy and Implementation
# Compliance (GDPR, PCI DSS)
# Technology Budgeting, Negotiation
# Experience
# BT Group
# 3 years 2 months
# Head of Engineering
# October 2022 - Present  (2 years 7 months)
# Snr Engineering Manager
# March 2022 - October 2022  (8 months)
# GBG Plc
# Engineering Development Manager
# February 2021 - March 2022  (1 year 2 months)
# FLEETCOR
# 5 years 8 months
# Vice President - UK & EU Development
# October 2017 - October 2020  (3 years 1 month)
# Birmingham, Walsall
# Director of Software Development - epyx
# July 2016 - October 2017  (1 year 4 months)
# Meriden
#   Page 2 of 4
# Driving the agile transformation across IT and the business creating cross-
# functional teams. Setting up product focused self-sufficient teams delivering
# iterative change, to enable the business to meet is revenue target. Using
# continual improvement metrics to create a positive and fun goal orientated
# environment.
# Implementing Devops pipeline using TFS, Octopus, MS test, JMeter and
# Selenium to increase change cadence while focusing on increasing quality.
# Working as part of the cross function team to manage the successful
# application migration to new data center.
# Director, Data Migration
# March 2015 - June 2016  (1 year 4 months)
# Managing multiple parallel migration projects, with a blend of onshore FTE
# leads and offshore resources. Working closely with the team to re-evaluate
# existing processes, and focus on business objectives.
# Transform the migration process to enable scaling of teams, improving
# planning process, introduction of TFS and change control process, increasing
# transparency and the impact of change on other teams and collaboration with
# stakeholders. Coaching teams to be independent and drive migration events.
# Bet365
# Software Development Team Leader
# April 2014 - March 2015  (1 year)
# Managing .Net developers, enhancing existing In-Play and Pre-game
# trading applications and models. Leading the delivery of a number of
# concurrent projects to time scale and budget in an energetic fast pace a
# diverse environment, where results are rewarded.
# Implementing SDLC changes, continually looking at the way we develop and
# deliver effectively.  Working with new and existing clients to consume data
# feeds, designing distributed multi-tiered applications, with SQL and message
# orientated design (ZeroMQ and RabbitMQ).
# FLEETCOR
# Development Team Lead
# March 2012 - March 2014  (2 years 1 month)
# walsall, united kingdom
#   Page 3 of 4
# Hands on leadership of a team of developers of varying experiences, and
# managing contractors in and out of projects. Working with teams in head office
# in Atlanta both in person and via remote working. Liaising with international
# clients to understand requirements and agree program of work. Monitoring
# sprints and personal performance against plan, and taking corrective action
# where need. Following up with staff to ensure lessons learnt and encouraging
# proactive behaviours.
# Using Microsoft technologies in a multi-tiered enterprise solution with
# ASP.net JQuery UI and C# over a federated database leveraging SQL Server
# replication to prevent process heavy jobs effecting customer experience, and
# using multi-threading to optimise performance and deliver a scalable product.
# Working with stakeholders to drive out functional requirements and user
# stories. Producing lightweight documents which support the agile development
# life cycle.
# Education
# Aberystwyth University
# Bsc, Freshwater and Marine Biology
# University of Wales, Aberystwyth
# MSc, Computer Science
#   Page 4 of 4

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Richard Bessey"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Richard Bessey. You are answering questions on Richard Bessey's website, particularly questions related to Richard Bessey's career, background, skills and experience. Your responsibility is to represent Richard Bessey for interactions on the website as faithfully as possible. You are given a summary of Richard Bessey's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Richard Bessey. I'm a software engineer and engiiner leader. I'm orginally from England but grew up in Wales, but i now live in the Midlands. I am oftern described as human dustbin as there is not a lot i wont eat.\nI love everthing out doors from running with my dogs, gardening canoeing to play hockey.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nrichard.bessey@hotmail.co.u\nk\nwww.linkedin.com/in/gbbessey\n(LinkedIn)\nTop Skills\nAmazon Web Services (AWS)\nMicroservices\nStrategic LeadershipRichard Bessey\nHands on Engineering leadership, Senior Engineering Leader | VP\nof Platform Engineering | Director of Software Engineering & Head of\nEngineering\nWalsall, England, United Kingdom\nSummary\nI thrive on diving deep into technical challenges and working hands-\non with customers and engineers to deliver impactful solutions. My\nleadership style is grounded in a strong engineering foundation,\nand I'm passionate about cultivating a culture of innovation,\ncraftsmanship, and continuous improvement—one that empowers\nengineers and enables outcome/value driven product development.\nWith over 15 years of experience across software engineering\nand engineering leadership, I've worked with teams of all sizes\n—from lean, focused squads to global engineering tribes of\n100+ professionals. I good at right-sizing teams for maximum\neffectiveness, recognizing that in today's AI-augmented landscape,\nsmall high-caliber teams often deliver the most value. My blend\nof strategic vision and technical knowledge allows me to scale\nplatforms, modernise architectures, and drive agile, cloud-native\ntransformation in complex, regulated industries.\nI remain committed to continuous learning, recently completing\nadvanced training in LLM engineering and currently building my\nfirst multi-agent AI solutions. This growing hands-on experience\nwith emerging technologies allows me to guide teams through\nAI exploration based on practical implementation rather than just\ntheoretical concepts.\nLocations: UK, Europe, and the USA\nIndustries: Financial Services, Retail, and Telecommunications\nRoles: VP of Platform Engineering, Director of Software Engineering,\nand Head of Engineering\nMy core skillset and key experience include:\nEmerging AI & LLM Engineering Skills (LangChain, Agent\nArchitectures, Prompt Engineering)\n\xa0 Page 1 of 4\xa0 \xa0\nTeam Optimization for Maximum Efficiency (from lean squads to\nlarger organizations)\nDigital Transformation with Measurable Impact\nTechnology Modernization that Delivers Clear Business Value\nScaling and Optimisation of Engineering Teams and Systems\nStrategy and Digital Agile Transformation\nEmotional Intelligence, Mentoring, and Coaching\nTechnology Roadmaps and Modern Enterprise Architecture\nDeep Technical Full Stack Experience\nMicroservices Architecture & Implementation (Java and Microsoft\nStack)\nCloud Engineering, Architecture, and Operating Models (Azure,\nAWS, and GCP)\nData Strategy and Implementation\nCompliance (GDPR, PCI DSS)\nTechnology Budgeting, Negotiation\nExperience\nBT Group\n3 years 2 months\nHead of Engineering\nOctober 2022\xa0-\xa0Present\xa0 (2 years 7 months)\nSnr Engineering Manager\nMarch 2022\xa0-\xa0October 2022\xa0 (8 months)\nGBG Plc\nEngineering Development Manager\nFebruary 2021\xa0-\xa0March 2022\xa0 (1 year 2 months)\nFLEETCOR\n5 years 8 months\nVice President - UK & EU Development\nOctobe ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += f"Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "No, I do not hold a patent. My focus has been primarily on software engineering and engineering leadership, where I've concentrated on delivering impactful solutions and driving innovation within teams. If you have any questions about my work or expertise, feel free to ask!"

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The response is acceptable. It's a concise and accurate answer to the question. The agent also helpfully offers to answer further questions, maintaining an engaging and professional tone.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + f"\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# This is not an acceptable response as the agent appears to be speaking in gibberish. I understand this is supposed to be Richard Bessey, but I'm not sure why the agent is speaking this way.
